# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Importing-libraries-and-reading-in-data" data-toc-modified-id="Importing-libraries-and-reading-in-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importing libraries and reading in data</a></span></li><li><span><a href="#Examining-data-with-counts-of-values-and-observations" data-toc-modified-id="Examining-data-with-counts-of-values-and-observations-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Examining data with counts of values and observations</a></span><ul class="toc-item"><li><span><a href="#Subject-age-group---encode-categorical,---is-dropped" data-toc-modified-id="Subject-age-group---encode-categorical,---is-dropped-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Subject age group - encode categorical, - is dropped</a></span></li><li><span><a href="#Repeated-subject-stops" data-toc-modified-id="Repeated-subject-stops-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Repeated subject stops</a></span></li><li><span><a href="#Stop-IDs,-some-are-repeated" data-toc-modified-id="Stop-IDs,-some-are-repeated-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Stop IDs, some are repeated</a></span></li><li><span><a href="#Where-are-the-duplicates?" data-toc-modified-id="Where-are-the-duplicates?-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Where are the duplicates?</a></span></li><li><span><a href="#Only-10---not-really-enough-to-derive-information-from" data-toc-modified-id="Only-10---not-really-enough-to-derive-information-from-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Only 10 - not really enough to derive information from</a></span></li><li><span><a href="#GO/SC-Number--ID---what-does-it-mean?-Has-multiple-occurrences-of-values." data-toc-modified-id="GO/SC-Number--ID---what-does-it-mean?-Has-multiple-occurrences-of-values.-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>GO/SC Number- ID - what does it mean? Has multiple occurrences of values.</a></span></li><li><span><a href="#Stop-resolution---could-be-treated-as-multiclass-or-binary-Arrest/No-Arrest" data-toc-modified-id="Stop-resolution---could-be-treated-as-multiclass-or-binary-Arrest/No-Arrest-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Stop resolution - could be treated as multiclass or binary Arrest/No Arrest</a></span></li><li><span><a href="#Weapons:-could-be-categorical,-and/or-boolean-presence" data-toc-modified-id="Weapons:-could-be-categorical,-and/or-boolean-presence-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Weapons: could be categorical, and/or boolean presence</a></span></li><li><span><a href="#Average-officer-stops-is-10---make-a-set-of-dataframe-of-above-average-stops-officers-vs.-below,-also-column-boolean-of-above-average-stops" data-toc-modified-id="Average-officer-stops-is-10---make-a-set-of-dataframe-of-above-average-stops-officers-vs.-below,-also-column-boolean-of-above-average-stops-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Average officer stops is 10 - make a set of dataframe of above average stops officers vs. below, also column boolean of above average stops</a></span></li><li><span><a href="#Frequent-officer-math-may-be-off" data-toc-modified-id="Frequent-officer-math-may-be-off-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Frequent officer math may be off</a></span></li><li><span><a href="#Officer-YOB-to-datetime,-consider-binning" data-toc-modified-id="Officer-YOB-to-datetime,-consider-binning-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Officer YOB to datetime, consider binning</a></span></li><li><span><a href="#Officer-race-can-become-white/not-boolean,-needs-imputing-unknown/what-to-do-with-that-and-not-specified" data-toc-modified-id="Officer-race-can-become-white/not-boolean,-needs-imputing-unknown/what-to-do-with-that-and-not-specified-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Officer race can become white/not boolean, needs imputing unknown/what to do with that and not specified</a></span></li><li><span><a href="#Subject-perceived-race-has---and-other-values,-can-be-white/boolean" data-toc-modified-id="Subject-perceived-race-has---and-other-values,-can-be-white/boolean-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Subject perceived race has - and other values, can be white/boolean</a></span></li><li><span><a href="#Subject-perceived-gender---unable-to-determine,---and-unknown-present" data-toc-modified-id="Subject-perceived-gender---unable-to-determine,---and-unknown-present-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Subject perceived gender - unable to determine, - and unknown present</a></span></li><li><span><a href="#Reported-date-to-datetime,-can-be-binned,-split,-usual-time-series-manipulation" data-toc-modified-id="Reported-date-to-datetime,-can-be-binned,-split,-usual-time-series-manipulation-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>Reported date to datetime, can be binned, split, usual time series manipulation</a></span></li><li><span><a href="#Reported-time-to-datetime,-can-be-binned" data-toc-modified-id="Reported-time-to-datetime,-can-be-binned-2.16"><span class="toc-item-num">2.16&nbsp;&nbsp;</span>Reported time to datetime, can be binned</a></span></li><li><span><a href="#This-is-botched-here-to-be-2020-03-26-and-needs-datetime-format=" data-toc-modified-id="This-is-botched-here-to-be-2020-03-26-and-needs-datetime-format=-2.17"><span class="toc-item-num">2.17&nbsp;&nbsp;</span>This is botched here to be 2020-03-26 and needs datetime format=</a></span></li><li><span><a href="#Initial-call-type-contrasts-with-Final-Call-Type,-worth-examining-the-differences" data-toc-modified-id="Initial-call-type-contrasts-with-Final-Call-Type,-worth-examining-the-differences-2.18"><span class="toc-item-num">2.18&nbsp;&nbsp;</span>Initial call type contrasts with Final Call Type, worth examining the differences</a></span></li><li><span><a href="#Officer-squads-needs-a-breakdown-and-investigation" data-toc-modified-id="Officer-squads-needs-a-breakdown-and-investigation-2.19"><span class="toc-item-num">2.19&nbsp;&nbsp;</span>Officer squads needs a breakdown and investigation</a></span></li><li><span><a href="#Average-arrests-for-a-squad-is-179" data-toc-modified-id="Average-arrests-for-a-squad-is-179-2.20"><span class="toc-item-num">2.20&nbsp;&nbsp;</span>Average arrests for a squad is 179</a></span></li><li><span><a href="#Arrest-flags" data-toc-modified-id="Arrest-flags-2.21"><span class="toc-item-num">2.21&nbsp;&nbsp;</span>Arrest flags</a></span></li><li><span><a href="#Frisk-flags" data-toc-modified-id="Frisk-flags-2.22"><span class="toc-item-num">2.22&nbsp;&nbsp;</span>Frisk flags</a></span></li><li><span><a href="#Geographic-variables---precinct,-possibly-sector-and-possibly-beat?" data-toc-modified-id="Geographic-variables---precinct,-possibly-sector-and-possibly-beat?-2.23"><span class="toc-item-num">2.23&nbsp;&nbsp;</span>Geographic variables - precinct, possibly sector and possibly beat?</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Slow-plots-first" data-toc-modified-id="Slow-plots-first-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Slow plots first</a></span></li><li><span><a href="#Pairplot-of-variables" data-toc-modified-id="Pairplot-of-variables-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Pairplot of variables</a></span></li><li><span><a href="#Correlation-matrix-heatmap-of-variables" data-toc-modified-id="Correlation-matrix-heatmap-of-variables-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Correlation matrix heatmap of variables</a></span></li><li><span><a href="#Stop-resolutions" data-toc-modified-id="Stop-resolutions-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Stop resolutions</a></span></li><li><span><a href="#Stops-with-weapon-vs.-none-present" data-toc-modified-id="Stops-with-weapon-vs.-none-present-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Stops with weapon vs. none present</a></span></li><li><span><a href="#Stops-with-weapon-present-and-arrest-or-not" data-toc-modified-id="Stops-with-weapon-present-and-arrest-or-not-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Stops with weapon present and arrest or not</a></span></li><li><span><a href="#Amount-of-stops-per-officer-histogram" data-toc-modified-id="Amount-of-stops-per-officer-histogram-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Amount of stops per officer histogram</a></span></li><li><span><a href="#Amount-of-stops-by-subject" data-toc-modified-id="Amount-of-stops-by-subject-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Amount of stops by subject</a></span></li><li><span><a href="#Distribution-and-nature-of-stops-by-officer-YOB" data-toc-modified-id="Distribution-and-nature-of-stops-by-officer-YOB-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Distribution and nature of stops by officer YOB</a></span></li><li><span><a href="#Officer-gender-distribution" data-toc-modified-id="Officer-gender-distribution-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Officer gender distribution</a></span></li><li><span><a href="#Arrests-by-female-officers" data-toc-modified-id="Arrests-by-female-officers-3.11"><span class="toc-item-num">3.11&nbsp;&nbsp;</span>Arrests by female officers</a></span></li><li><span><a href="#Officer-Race-distribution" data-toc-modified-id="Officer-Race-distribution-3.12"><span class="toc-item-num">3.12&nbsp;&nbsp;</span>Officer Race distribution</a></span></li><li><span><a href="#Arrests-by-non-white-officers" data-toc-modified-id="Arrests-by-non-white-officers-3.13"><span class="toc-item-num">3.13&nbsp;&nbsp;</span>Arrests by non-white officers</a></span></li><li><span><a href="#Suspect?-Subject?-perceived-race" data-toc-modified-id="Suspect?-Subject?-perceived-race-3.14"><span class="toc-item-num">3.14&nbsp;&nbsp;</span>Suspect? Subject? perceived race</a></span></li><li><span><a href="#Suspect-perceived-gender" data-toc-modified-id="Suspect-perceived-gender-3.15"><span class="toc-item-num">3.15&nbsp;&nbsp;</span>Suspect perceived gender</a></span></li><li><span><a href="#Stops-of-female-suspects" data-toc-modified-id="Stops-of-female-suspects-3.16"><span class="toc-item-num">3.16&nbsp;&nbsp;</span>Stops of female suspects</a></span></li><li><span><a href="#Suspect-age-groups" data-toc-modified-id="Suspect-age-groups-3.17"><span class="toc-item-num">3.17&nbsp;&nbsp;</span>Suspect age groups</a></span></li><li><span><a href="#Repeat-subjects" data-toc-modified-id="Repeat-subjects-3.18"><span class="toc-item-num">3.18&nbsp;&nbsp;</span>Repeat subjects</a></span></li><li><span><a href="#Initial-and-final-call-types---too-small-y-labels" data-toc-modified-id="Initial-and-final-call-types---too-small-y-labels-3.19"><span class="toc-item-num">3.19&nbsp;&nbsp;</span>Initial and final call types - too small y labels</a></span></li><li><span><a href="#Examination-of-officer-squads" data-toc-modified-id="Examination-of-officer-squads-3.20"><span class="toc-item-num">3.20&nbsp;&nbsp;</span>Examination of officer squads</a></span></li><li><span><a href="#Arrest-flags" data-toc-modified-id="Arrest-flags-3.21"><span class="toc-item-num">3.21&nbsp;&nbsp;</span>Arrest flags</a></span></li><li><span><a href="#Nature-of-arrests" data-toc-modified-id="Nature-of-arrests-3.22"><span class="toc-item-num">3.22&nbsp;&nbsp;</span>Nature of arrests</a></span></li><li><span><a href="#Frisk-flags" data-toc-modified-id="Frisk-flags-3.23"><span class="toc-item-num">3.23&nbsp;&nbsp;</span>Frisk flags</a></span></li><li><span><a href="#Nature-of-frisks" data-toc-modified-id="Nature-of-frisks-3.24"><span class="toc-item-num">3.24&nbsp;&nbsp;</span>Nature of frisks</a></span></li><li><span><a href="#Arrests-by-Frisk-vs.-No-Frisk---make-subplots" data-toc-modified-id="Arrests-by-Frisk-vs.-No-Frisk---make-subplots-3.25"><span class="toc-item-num">3.25&nbsp;&nbsp;</span>Arrests by Frisk vs. No Frisk - make subplots</a></span></li></ul></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Feature Engineering</a></span></li><li><span><a href="#EDA-Part-2" data-toc-modified-id="EDA-Part-2-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>EDA Part 2</a></span></li></ul></div>

# %% [markdown]
# # Importing libraries and reading in data

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Terry_Stops.csv')

df.head(20)
# Out:
# /Users/michael/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Subject Age Group  Subject ID     GO / SC Num  Terry Stop ID  \
# 0                  -          -1  20140000120677          92317
# 1                  -          -1  20150000001670          32260
# 2                  -          -1  20150000002451          46430
# 3                  -          -1  20150000002815          51725
# 4                  -          -1  20150000002815          51727
# 5                  -          -1  20150000002833          52168
# 6                  -          -1  20150000002856          52559
# 7                  -          -1  20150000002870          52057
# 8                  -          -1  20150000003188          57803
# ...

# %%
len(df)
# Out:
# 40585

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40585 entries, 0 to 40584
# Data columns (total 23 columns):
# Subject Age Group           40585 non-null object
# Subject ID                  40585 non-null int64
# GO / SC Num                 40585 non-null int64
# Terry Stop ID               40585 non-null int64
# Stop Resolution             40585 non-null object
# Weapon Type                 40585 non-null object
# Officer ID                  40585 non-null object
# Officer YOB                 40585 non-null int64
# Officer Gender              40585 non-null object
# Officer Race                40585 non-null object
# Subject Perceived Race      40585 non-null object
# Subject Perceived Gender    40585 non-null object
# Reported Date               40585 non-null object
# Reported Time               40585 non-null object
# Initial Call Type           40585 non-null object
# Final Call Type             40585 non-null object
# Call Type                   40585 non-null object
# ...

# %%
df.columns
# Out:
# Index(['Subject Age Group', 'Subject ID', 'GO / SC Num', 'Terry Stop ID',
#        'Stop Resolution', 'Weapon Type', 'Officer ID', 'Officer YOB',
#        'Officer Gender', 'Officer Race', 'Subject Perceived Race',
#        'Subject Perceived Gender', 'Reported Date', 'Reported Time',
#        'Initial Call Type', 'Final Call Type', 'Call Type', 'Officer Squad',
#        'Arrest Flag', 'Frisk Flag', 'Precinct', 'Sector', 'Beat'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ', '_')

df.columns
# Out:
# Index(['Subject_Age_Group', 'Subject_ID', 'GO_/_SC_Num', 'Terry_Stop_ID',
#        'Stop_Resolution', 'Weapon_Type', 'Officer_ID', 'Officer_YOB',
#        'Officer_Gender', 'Officer_Race', 'Subject_Perceived_Race',
#        'Subject_Perceived_Gender', 'Reported_Date', 'Reported_Time',
#        'Initial_Call_Type', 'Final_Call_Type', 'Call_Type', 'Officer_Squad',
#        'Arrest_Flag', 'Frisk_Flag', 'Precinct', 'Sector', 'Beat'],
#       dtype='object')

# %% [markdown]
# ### Should probably case those columns appropriately for dot access.

# %% [markdown]
# # Examining data with counts of values and observations

# %% [markdown]
# ## Subject age group - encode categorical, - is dropped

# %%
df['Subject_Age_Group'].value_counts(dropna=False)
# Out:
# 26 - 35         13457
# 18 - 25          8442
# 36 - 45          8412
# 46 - 55          5198
# 56 and Above     1947
# 1 - 17           1864
# -                1265
# Name: Subject_Age_Group, dtype: int64

# %%
#do something with the repeat suspects, at least EDA? -1 is probably missing data
df['Subject_ID'].value_counts(dropna=False)
# Out:
# -1              34632
#  7726859935         9
#  7727827572         6
#  7753260438         6
#  7726859806         5
#                 ...
#  8245283701         1
#  8228066174         1
#  7725525905         1
#  7726578579         1
#  11716939786        1
# Name: Subject_ID, Length: 5069, dtype: int64

# %% [markdown]
# ## Repeated subject stops

# %%
repeat_subjects = df.groupby('Subject_ID').filter(lambda x: len(x) > 2)

repeat_subjects = repeat_subjects[repeat_subjects['Subject_ID'] != '-1']
repeat_subjects
# Out:
# /Users/michael/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
#       Subject_Age_Group   Subject_ID     GO_/_SC_Num  Terry_Stop_ID  \
# 0                     -           -1  20140000120677          92317
# 1                     -           -1  20150000001670          32260
# 2                     -           -1  20150000002451          46430
# 3                     -           -1  20150000002815          51725
# 4                     -           -1  20150000002815          51727
# ...                 ...          ...             ...            ...
# 40465      56 and Above   8247677733  20190000257366     8613708044
# 40484      56 and Above   8247677733  20190000301249     9668116340
# 40532      56 and Above  10517709098  20190000362551    10517706653
# ...

# %%
rep_subj_idx = repeat_subjects.index

# %%
df['Repeat_Subject'] = 0
df['Repeat_Subject'].loc[rep_subj_idx] = 1

df.tail(20)
# Out:
# /Users/michael/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#       Subject_Age_Group   Subject_ID     GO_/_SC_Num  Terry_Stop_ID  \
# 40565      56 and Above  12758662744  20200000090911    12758656627
# 40566      56 and Above  11686870601  20190000412917    11686872833
# 40567      56 and Above  11824772851  20190000425679    11827070818
# 40568      56 and Above  11890694315  20190000436479    11891509431
# 40569      56 and Above  12628301933  20200000063118    12628219617
# 40570      56 and Above  12751420204  20200000099744    12782197686
# 40571      56 and Above  12770732072  20200000092706    12770725038
# ...

# %% [markdown]
# ## Stop IDs, some are repeated

# %%
df['Terry_Stop_ID'].value_counts(dropna=False)
# Out:
# 12034618758    2
# 12689034912    2
# 12119304761    2
# 12608907801    2
# 8677596250     2
#               ..
# 195178         1
# 254569         1
# 387688         1
# 234087         1
# 131072         1
# Name: Terry_Stop_ID, Length: 40575, dtype: int64

# %%
df.duplicated(['Terry_Stop_ID']).sum()
# Out:
# 10

# %%
stop_dupes = df.duplicated(['Terry_Stop_ID'])

stop_dupes
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40580    False
# 40581    False
# 40582    False
# 40583    False
# 40584    False
# Length: 40585, dtype: bool

# %%
stop_dupe_idx = stop_dupes[stop_dupes]

len(stop_dupe_idx)
# Out:
# 10

# %%
stop_dupe_vals = stop_dupes[stop_dupes].index.values

# %% [markdown]
# ## Where are the duplicates?

# %%
stop_dupe_df = df[df.index.isin(stop_dupe_vals)]

stop_dupe_df
# Out:
#       Subject_Age_Group   Subject_ID     GO_/_SC_Num  Terry_Stop_ID  \
# 3139             1 - 17  11637443950  20190000465104    12105013403
# 11066           18 - 25   7764935851  20200000080922    12689034912
# 11291           18 - 25   9458419522  20190000285750     9585545373
# 11437           18 - 25  11896724492  20190000454262    12034618758
# 23212           26 - 35   7726127566  20200000040587    12601385662
# 23689           26 - 35   7730805128  20190000268604     8677596250
# 23758           26 - 35   7731973837  20190000479273    12119304761
# 24293           26 - 35   7805394791  20200000047411    12608907801
# 24327           26 - 35   7810387129  20190000254490     8611673538
# 40468      56 and Above   7814963710  20200000099547    12781960580
#
#       Stop_Resolution                        Weapon_Type Officer_ID  \
# 3139           Arrest                  Mace/Pepper Spray     8500
# 11066   Field Contact    Blunt Object/Striking Implement     7667
# ...

# %% [markdown]
# ## Only 10 - not really enough to derive information from

# %% [markdown]
# ## GO/SC Number- ID - what does it mean? Has multiple occurrences of values.

# %%
df['GO_/_SC_Num'].value_counts(dropna=False)
# Out:
# 20150000190790    16
# 20160000378750    16
# 20180000134604    14
# 20170000132836    13
# 20180000002716    12
#                   ..
# 20160000147949     1
# 20200000028904     1
# 20150000005603     1
# 20160000008673     1
# 20180000071981     1
# Name: GO_/_SC_Num, Length: 31444, dtype: int64

# %% [markdown]
# ## Stop resolution - could be treated as multiclass or binary Arrest/No Arrest

# %%
# categorical target this should be a multiclass problem
df['Stop_Resolution'].value_counts(dropna=False)
# Out:
# Field Contact               15933
# Offense Report              13902
# Arrest                       9868
# Referred for Prosecution      728
# Citation / Infraction         154
# Name: Stop_Resolution, dtype: int64

# %%
not_arrest = ['Offense Report', 'Field Contact', 'Referred for Prosecution', 'Citation / Infraction']
stop_results = {'Arrest': 1, 'Offense Report': 0, 'Field Contact':0,'Referred for Prosecution':0, 'Citation / Infraction':0}

df['Arrested'] = df['Stop_Resolution'].map(stop_results)

df.tail(20)
# Out:
#       Subject_Age_Group   Subject_ID     GO_/_SC_Num  Terry_Stop_ID  \
# 40565      56 and Above  12758662744  20200000090911    12758656627
# 40566      56 and Above  11686870601  20190000412917    11686872833
# 40567      56 and Above  11824772851  20190000425679    11827070818
# 40568      56 and Above  11890694315  20190000436479    11891509431
# 40569      56 and Above  12628301933  20200000063118    12628219617
# 40570      56 and Above  12751420204  20200000099744    12782197686
# 40571      56 and Above  12770732072  20200000092706    12770725038
# 40572      56 and Above  12778364183  20200000097347    12778351341
# 40573      56 and Above  10095435952  20190000330748    10095571496
# 40574      56 and Above  10396547789  20190000354852    10396540580
# 40575      56 and Above  10517709098  20200000069970    12635860876
# 40576      56 and Above  11130953753  20190000384778    11130956909
# 40577      56 and Above  11163172632  20190000394628    11162908074
# ...

# %% [markdown]
# ## Weapons: could be categorical, and/or boolean presence

# %%
df['Weapon_Type'].value_counts(dropna=False)
# Out:
# None                                 32565
# -                                     5735
# Lethal Cutting Instrument             1482
# Knife/Cutting/Stabbing Instrument      276
# Handgun                                262
# Firearm Other                          100
# Club, Blackjack, Brass Knuckles         49
# Blunt Object/Striking Implement         31
# Firearm                                 18
# Firearm (unk type)                      15
# Other Firearm                           12
# Mace/Pepper Spray                       10
# Club                                     9
# Rifle                                    5
# Taser/Stun Gun                           4
# None/Not Applicable                      4
# Shotgun                                  3
# Automatic Handgun                        2
# Fire/Incendiary Device                   1
# Blackjack                                1
# Brass Knuckles                           1
# Name: Weapon_Type, dtype: int64

# %%
df['Weapon_Type'].unique()
# Out:
# array(['None', 'Lethal Cutting Instrument', 'Firearm Other', 'Handgun',
#        '-', 'Club, Blackjack, Brass Knuckles',
#        'Knife/Cutting/Stabbing Instrument', 'Rifle',
#        'Fire/Incendiary Device', 'Firearm (unk type)', 'Other Firearm',
#        'Mace/Pepper Spray', 'Club', 'Blunt Object/Striking Implement',
#        'Firearm', 'Shotgun', 'Brass Knuckles', 'Automatic Handgun',
#        'Taser/Stun Gun', 'None/Not Applicable', 'Blackjack'], dtype=object)

# %%
df['Weapon_Present'] = df['Weapon_Type'].map({'None':0, 'Lethal Cutting Instrument':1, 'Firearm Other':1, 'Handgun':1,
       '-':0, 'Club':1, 'Blackjack':1, 'Brass Knuckles':1,
       'Knife/Cutting/Stabbing Instrument':1, 'Rifle':1,
       'Fire/Incendiary Device':1, 'Firearm (unk type)':1, 'Other Firearm':1,
       'Mace/Pepper Spray':1, 'Club':1, 'Blunt Object/Striking Implement':1,
       'Firearm':1, 'Shotgun':1, 'Brass Knuckles':1, 'Automatic Handgun':1,
       'Taser/Stun Gun':1, 'None/Not Applicable':0, 'Blackjack':1})

df.tail(20)
# Out:
#       Subject_Age_Group   Subject_ID     GO_/_SC_Num  Terry_Stop_ID  \
# 40565      56 and Above  12758662744  20200000090911    12758656627
# 40566      56 and Above  11686870601  20190000412917    11686872833
# 40567      56 and Above  11824772851  20190000425679    11827070818
# 40568      56 and Above  11890694315  20190000436479    11891509431
# 40569      56 and Above  12628301933  20200000063118    12628219617
# 40570      56 and Above  12751420204  20200000099744    12782197686
# 40571      56 and Above  12770732072  20200000092706    12770725038
# 40572      56 and Above  12778364183  20200000097347    12778351341
# 40573      56 and Above  10095435952  20190000330748    10095571496
# 40574      56 and Above  10396547789  20190000354852    10396540580
# 40575      56 and Above  10517709098  20200000069970    12635860876
# 40576      56 and Above  11130953753  20190000384778    11130956909
# 40577      56 and Above  11163172632  20190000394628    11162908074
# ...

# %%
df['Weapon_Present'].value_counts()
# Out:
# 0.0    38304
# 1.0     2232
# Name: Weapon_Present, dtype: int64

# %% [markdown]
# ## Average officer stops is 10 - make a set of dataframe of above average stops officers vs. below, also column boolean of above average stops

# %%
# categorical, interesting high values
df['Officer_ID'].value_counts(dropna=False)
# Out:
# 7456      314
# 7634      275
# 7773      249
# 7758      236
# 7765      216
#          ...
# 6855        1
# 6287        1
# 5833        1
# 4311        1
# 4835        1
# Name: Officer_ID, Length: 2028, dtype: int64

# %%
df['Officer_ID'].value_counts(dropna=False).median()
# Out:
# 10.0

# %%
df['Officer_ID'].value_counts(dropna=False).describe()
# Out:
# count    2028.000000
# mean       20.012327
# std        28.612260
# min         1.000000
# 25%         3.000000
# 50%        10.000000
# 75%        24.000000
# max       314.000000
# Name: Officer_ID, dtype: float64

# %% [markdown]
# ## Frequent officer math may be off

# %%
officer_counts = df['Officer_ID'].value_counts()
off_ct_idx = officer_counts[officer_counts > 24]

# %%
off_ct_idx
# Out:
# 7456      314
# 7634      275
# 7773      249
# 7758      236
# 7765      216
#          ...
# 6603       25
# 8662       25
# 8559       25
# 6106       25
# 7654       25
# Name: Officer_ID, Length: 502, dtype: int64

# %%
df['Frequent_Officer'] = 0 
df['Frequent_Officer'].loc[off_ct_idx] = 1

df.tail(20)
# Out:
#       Subject_Age_Group   Subject_ID     GO_/_SC_Num  Terry_Stop_ID  \
# 40565      56 and Above  12758662744  20200000090911    12758656627
# 40566      56 and Above  11686870601  20190000412917    11686872833
# 40567      56 and Above  11824772851  20190000425679    11827070818
# 40568      56 and Above  11890694315  20190000436479    11891509431
# 40569      56 and Above  12628301933  20200000063118    12628219617
# 40570      56 and Above  12751420204  20200000099744    12782197686
# 40571      56 and Above  12770732072  20200000092706    12770725038
# 40572      56 and Above  12778364183  20200000097347    12778351341
# 40573      56 and Above  10095435952  20190000330748    10095571496
# 40574      56 and Above  10396547789  20190000354852    10396540580
# 40575      56 and Above  10517709098  20200000069970    12635860876
# 40576      56 and Above  11130953753  20190000384778    11130956909
# 40577      56 and Above  11163172632  20190000394628    11162908074
# ...

# %%
df.head()
# Out:
#   Subject_Age_Group  Subject_ID     GO_/_SC_Num  Terry_Stop_ID  \
# 0                 -          -1  20140000120677          92317
# 1                 -          -1  20150000001670          32260
# 2                 -          -1  20150000002451          46430
# 3                 -          -1  20150000002815          51725
# 4                 -          -1  20150000002815          51727
#
#   Stop_Resolution Weapon_Type Officer_ID  Officer_YOB Officer_Gender  \
# 0          Arrest        None     7500           1984              M
# 1   Field Contact        None     7539           1963              M
# 2   Field Contact        None     7591           1985              M
# 3   Field Contact        None     7456           1979              M
# 4   Field Contact        None     7456           1979              M
#
#                 Officer_Race  ...             Officer_Squad Arrest_Flag  \
# 0  Black or African American  ...  SOUTH PCT 1ST W - ROBERT           N
# ...

# %% [markdown]
# ## Officer YOB to datetime, consider binning

# %%
df['Officer_YOB'].value_counts(dropna=False)
# Out:
# 1986    2899
# 1987    2562
# 1984    2537
# 1985    2314
# 1991    2310
# 1992    2002
# 1990    1859
# 1988    1807
# 1982    1723
# 1989    1710
# 1983    1577
# 1979    1347
# 1981    1265
# 1971    1174
# 1993    1066
# 1978    1035
# 1977     932
# 1976     894
# 1973     852
# 1980     753
# 1995     731
# 1967     680
# 1968     574
# 1994     568
# 1970     540
# 1974     520
# 1969     511
# 1975     472
# 1962     444
# 1965     400
# 1964     391
# 1972     391
# 1963     226
# 1996     223
# 1958     218
# 1966     214
# 1961     199
# 1959     174
# 1960     154
# 1997     147
# 1954      43
# 1957      41
# 1953      32
# 1955      21
# 1956      16
# 1948      11
# 1900       9
# 1952       9
# 1949       5
# 1946       2
# 1951       1
# Name: Officer_YOB, dtype: int64

# %%
df['Officer_YOB'] =  pd.to_datetime(df['Officer_YOB'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40585 entries, 0 to 40584
# Data columns (total 27 columns):
# Subject_Age_Group           40585 non-null object
# Subject_ID                  40585 non-null int64
# GO_/_SC_Num                 40585 non-null int64
# Terry_Stop_ID               40585 non-null int64
# Stop_Resolution             40585 non-null object
# Weapon_Type                 40585 non-null object
# Officer_ID                  40585 non-null object
# Officer_YOB                 40585 non-null datetime64[ns]
# Officer_Gender              40585 non-null object
# Officer_Race                40585 non-null object
# Subject_Perceived_Race      40585 non-null object
# Subject_Perceived_Gender    40585 non-null object
# Reported_Date               40585 non-null object
# Reported_Time               40585 non-null object
# Initial_Call_Type           40585 non-null object
# Final_Call_Type             40585 non-null object
# ...

# %%
df['Officer_YOB']
# Out:
# 0       1970-01-01 00:00:00.000001984
# 1       1970-01-01 00:00:00.000001963
# 2       1970-01-01 00:00:00.000001985
# 3       1970-01-01 00:00:00.000001979
# 4       1970-01-01 00:00:00.000001979
#                      ...
# 40580   1970-01-01 00:00:00.000001972
# 40581   1970-01-01 00:00:00.000001985
# 40582   1970-01-01 00:00:00.000001987
# 40583   1970-01-01 00:00:00.000001995
# 40584   1970-01-01 00:00:00.000001969
# Name: Officer_YOB, Length: 40585, dtype: datetime64[ns]

# %%
#impute N? categorical
df['Officer_Gender'].value_counts(dropna=False)
# Out:
# M    36062
# F     4516
# N        7
# Name: Officer_Gender, dtype: int64

# %%
#impute

# %% [markdown]
# ## Officer race can become white/not boolean, needs imputing unknown/what to do with that and not specified

# %%
df['Officer_Race'].value_counts(dropna=False)
# Out:
# White                            31404
# Hispanic or Latino                2230
# Two or More Races                 2122
# Black or African American         1647
# Asian                             1536
# Not Specified                      911
# Nat Hawaiian/Oth Pac Islander      418
# American Indian/Alaska Native      308
# Unknown                              9
# Name: Officer_Race, dtype: int64

# %%
#impute

# %%
white_off_idx = df[df['Officer_Race'] == "White"].index

white_off_idx
# Out:
# Int64Index([    1,     3,     4,     5,     7,     9,    10,    11,    17,
#                19,
#             ...
#             40572, 40574, 40575, 40577, 40578, 40580, 40581, 40582, 40583,
#             40584],
#            dtype='int64', length=31404)

# %%
df['White_Officer'] = 0 
df['White_Officer'].loc[white_off_idx] = 1

df.tail(20)
# Out:
#       Subject_Age_Group   Subject_ID     GO_/_SC_Num  Terry_Stop_ID  \
# 40565      56 and Above  12758662744  20200000090911    12758656627
# 40566      56 and Above  11686870601  20190000412917    11686872833
# 40567      56 and Above  11824772851  20190000425679    11827070818
# 40568      56 and Above  11890694315  20190000436479    11891509431
# 40569      56 and Above  12628301933  20200000063118    12628219617
# 40570      56 and Above  12751420204  20200000099744    12782197686
# 40571      56 and Above  12770732072  20200000092706    12770725038
# 40572      56 and Above  12778364183  20200000097347    12778351341
# 40573      56 and Above  10095435952  20190000330748    10095571496
# 40574      56 and Above  10396547789  20190000354852    10396540580
# 40575      56 and Above  10517709098  20200000069970    12635860876
# 40576      56 and Above  11130953753  20190000384778    11130956909
# 40577      56 and Above  11163172632  20190000394628    11162908074
# ...

# %% [markdown]
# ## Subject perceived race has - and other values, can be white/boolean

# %%
df['Subject_Perceived_Race'].value_counts(dropna=False)
# Out:
# White                                        19922
# Black or African American                    12114
# Unknown                                       2041
# Hispanic                                      1684
# -                                             1367
# Asian                                         1255
# American Indian or Alaska Native              1216
# Multi-Racial                                   809
# Other                                          152
# Native Hawaiian or Other Pacific Islander       25
# Name: Subject_Perceived_Race, dtype: int64

# %%
#impute

# %%
white_sub_idx = df[df['Subject_Perceived_Race'] == "White"].index

df['White_Subject'] = 0 
df['White_Subject'].loc[white_sub_idx] = 1

df.tail(20)
# Out:
#       Subject_Age_Group   Subject_ID     GO_/_SC_Num  Terry_Stop_ID  \
# 40565      56 and Above  12758662744  20200000090911    12758656627
# 40566      56 and Above  11686870601  20190000412917    11686872833
# 40567      56 and Above  11824772851  20190000425679    11827070818
# 40568      56 and Above  11890694315  20190000436479    11891509431
# 40569      56 and Above  12628301933  20200000063118    12628219617
# 40570      56 and Above  12751420204  20200000099744    12782197686
# 40571      56 and Above  12770732072  20200000092706    12770725038
# 40572      56 and Above  12778364183  20200000097347    12778351341
# 40573      56 and Above  10095435952  20190000330748    10095571496
# 40574      56 and Above  10396547789  20190000354852    10396540580
# 40575      56 and Above  10517709098  20200000069970    12635860876
# 40576      56 and Above  11130953753  20190000384778    11130956909
# 40577      56 and Above  11163172632  20190000394628    11162908074
# ...

# %%
bl_sub_idx = df[df['Subject_Perceived_Race'] == "Black or African American"].index

df['Black_Subject'] = 0 
df['Black_Subject'].loc[bl_sub_idx] = 1

df.tail(20)
# Out:
#       Subject_Age_Group   Subject_ID     GO_/_SC_Num  Terry_Stop_ID  \
# 40565      56 and Above  12758662744  20200000090911    12758656627
# 40566      56 and Above  11686870601  20190000412917    11686872833
# 40567      56 and Above  11824772851  20190000425679    11827070818
# 40568      56 and Above  11890694315  20190000436479    11891509431
# 40569      56 and Above  12628301933  20200000063118    12628219617
# 40570      56 and Above  12751420204  20200000099744    12782197686
# 40571      56 and Above  12770732072  20200000092706    12770725038
# 40572      56 and Above  12778364183  20200000097347    12778351341
# 40573      56 and Above  10095435952  20190000330748    10095571496
# 40574      56 and Above  10396547789  20190000354852    10396540580
# 40575      56 and Above  10517709098  20200000069970    12635860876
# 40576      56 and Above  11130953753  20190000384778    11130956909
# 40577      56 and Above  11163172632  20190000394628    11162908074
# ...

# %% [markdown]
# ## Subject perceived gender - unable to determine, - and unknown present

# %%
df['Subject_Perceived_Gender'].value_counts(dropna=False)
# Out:
# Male                                                         31600
# Female                                                        8400
# Unable to Determine                                            326
# -                                                              253
# Unknown                                                          5
# Gender Diverse (gender non-conforming and/or transgender)        1
# Name: Subject_Perceived_Gender, dtype: int64

# %%
#impute

# %% [markdown]
# ## Reported date to datetime, can be binned, split, usual time series manipulation

# %%
#datetime, produce some plots
df['Reported_Date'].value_counts(dropna=False)
# Out:
# 2015-10-01T00:00:00    101
# 2015-09-29T00:00:00     66
# 2015-05-28T00:00:00     57
# 2015-07-18T00:00:00     55
# 2019-04-26T00:00:00     54
#                       ...
# 2015-04-14T00:00:00      1
# 2015-05-10T00:00:00      1
# 2015-03-28T00:00:00      1
# 2015-05-06T00:00:00      1
# 2015-03-31T00:00:00      1
# Name: Reported_Date, Length: 1837, dtype: int64

# %%
df['Reported_Date'] =  pd.to_datetime(df['Reported_Date'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40585 entries, 0 to 40584
# Data columns (total 30 columns):
# Subject_Age_Group           40585 non-null object
# Subject_ID                  40585 non-null int64
# GO_/_SC_Num                 40585 non-null int64
# Terry_Stop_ID               40585 non-null int64
# Stop_Resolution             40585 non-null object
# Weapon_Type                 40585 non-null object
# Officer_ID                  40585 non-null object
# Officer_YOB                 40585 non-null datetime64[ns]
# Officer_Gender              40585 non-null object
# Officer_Race                40585 non-null object
# Subject_Perceived_Race      40585 non-null object
# Subject_Perceived_Gender    40585 non-null object
# Reported_Date               40585 non-null datetime64[ns]
# Reported_Time               40585 non-null object
# Initial_Call_Type           40585 non-null object
# Final_Call_Type             40585 non-null object
# ...

# %%
df['Reported_Date'].head(10)
# Out:
# 0   2015-10-16
# 1   2015-04-01
# 2   2015-05-25
# 3   2015-06-09
# 4   2015-06-09
# 5   2015-06-11
# 6   2015-06-12
# 7   2015-06-12
# 8   2015-06-27
# 9   2015-07-02
# Name: Reported_Date, dtype: datetime64[ns]

# %% [markdown]
# ## Reported time to datetime, can be binned

# %%
#split up the time variables
df['Reported_Time'].value_counts(dropna=False)
# Out:
# 19:18:00    51
# 03:13:00    50
# 02:56:00    50
# 03:09:00    50
# 18:51:00    49
#             ..
# 18:12:01     1
# 17:51:36     1
# 11:09:06     1
# 19:53:44     1
# 14:32:04     1
# Name: Reported_Time, Length: 7168, dtype: int64

# %%
df['Reported_Time'] =  pd.to_datetime(df['Reported_Time'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40585 entries, 0 to 40584
# Data columns (total 30 columns):
# Subject_Age_Group           40585 non-null object
# Subject_ID                  40585 non-null int64
# GO_/_SC_Num                 40585 non-null int64
# Terry_Stop_ID               40585 non-null int64
# Stop_Resolution             40585 non-null object
# Weapon_Type                 40585 non-null object
# Officer_ID                  40585 non-null object
# Officer_YOB                 40585 non-null datetime64[ns]
# Officer_Gender              40585 non-null object
# Officer_Race                40585 non-null object
# Subject_Perceived_Race      40585 non-null object
# Subject_Perceived_Gender    40585 non-null object
# Reported_Date               40585 non-null datetime64[ns]
# Reported_Time               40585 non-null datetime64[ns]
# Initial_Call_Type           40585 non-null object
# Final_Call_Type             40585 non-null object
# ...

# %%
df['Reported_Time'].head(10)
# Out:
# 0   2020-03-26 11:32:00
# 1   2020-03-26 04:55:00
# 2   2020-03-26 01:06:00
# 3   2020-03-26 19:27:00
# 4   2020-03-26 19:32:00
# 5   2020-03-26 01:25:00
# 6   2020-03-26 04:44:00
# 7   2020-03-26 14:32:00
# 8   2020-03-26 05:12:00
# 9   2020-03-26 00:25:00
# Name: Reported_Time, dtype: datetime64[ns]

# %% [markdown]
# ## This is botched here to be 2020-03-26 and needs datetime format=

# %% [markdown]
# ## Initial call type contrasts with Final Call Type, worth examining the differences

# %%
# - is an issue, encode
df['Initial_Call_Type'].value_counts(dropna=False)
# Out:
# -                                                 12728
# SUSPICIOUS PERSON, VEHICLE OR INCIDENT             2450
# SUSPICIOUS STOP - OFFICER INITIATED ONVIEW         2390
# DISTURBANCE, MISCELLANEOUS/OTHER                   2094
# ASLT - IP/JO - WITH OR W/O WPNS (NO SHOOTINGS)     1686
#                                                   ...
# KNOWN KIDNAPPNG                                       1
# ALARM - ATM MACHINE, FREE STANDING                    1
# DEMONSTRATIONS                                        1
# ANIMAL, REPORT - BITE                                 1
# ESCAPE - PRISONER                                     1
# Name: Initial_Call_Type, Length: 161, dtype: int64

# %%
#impute

# %%
# - is an issue, encode, including differences between initial 
df['Final_Call_Type'].value_counts(dropna=False)
# Out:
# -                                                 12728
# --SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON           2909
# --PROWLER - TRESPASS                               2596
# --DISTURBANCE - OTHER                              2272
# --ASSAULTS, OTHER                                  1949
#                                                   ...
# -ASSIGNED DUTY - FOOT BEAT (FROM ASSIGNED CAR)        1
# -ASSIGNED DUTY - STAKEOUT                             1
# --CROWD MGMNT (STAND BY ONLY)                         1
# MVC - NON INJURY, BLOCKING                            1
# DUI - DRIVING UNDER INFLUENCE                         1
# Name: Final_Call_Type, Length: 193, dtype: int64

# %%
#impute

# %%
#categorical simple encode, combinations with other columns, - values present
df['Call_Type'].value_counts(dropna=False)
# Out:
# 911                              17578
# -                                12728
# ONVIEW                            7271
# TELEPHONE OTHER, NOT 911          2785
# ALARM CALL (NOT POLICE ALARM)      218
# PROACTIVE (OFFICER INITIATED)        2
# TEXT MESSAGE                         2
# SCHEDULED EVENT (RECURRING)          1
# Name: Call_Type, dtype: int64

# %%
#impute

# %% [markdown]
# ## Officer squads needs a breakdown and investigation

# %%
df['Officer_Squad'].value_counts(dropna=False)
# Out:
# TRAINING - FIELD TRAINING SQUAD                   4260
# WEST PCT 1ST W - DAVID/MARY                       1264
# NORTH PCT 2ND WATCH - NORTH BEATS                  878
# WEST PCT 2ND W - D/M RELIEF                        853
# SOUTHWEST PCT 2ND W - FRANK                        829
#                                                   ...
# BURG/THEFT/JUV - NORTH                               1
# COMM - INTERNET AND TELEPHONE REPORTING (ITRU)       1
# RECORDS - DAY SHIFT                                  1
# NAVIGATION TEAM - SQUAD B                            1
# ZOLD CRIME ANALYSIS UNIT - ANALYSTS                  1
# Name: Officer_Squad, Length: 159, dtype: int64

# %% [markdown]
# ## Average arrests for a squad is 179

# %%
df['Officer_Squad'].value_counts(dropna=False).median()
# Out:
# 179.0

# %% [markdown]
# ## Arrest flags

# %%
df['Arrest_Flag'].value_counts(dropna=False)
# Out:
# N    38925
# Y     1660
# Name: Arrest_Flag, dtype: int64

# %% [markdown]
# ## Frisk flags

# %%
#impute as N?
df['Frisk_Flag'].value_counts(dropna=False)
# Out:
# N    31201
# Y     8907
# -      477
# Name: Frisk_Flag, dtype: int64

# %% [markdown]
# ## Geographic variables - precinct, possibly sector and possibly beat?

# %%
#A lot of missing values, but there's a map in here for sure
df['Precinct'].value_counts(dropna=False)
# Out:
# -            9448
# North        9094
# West         8691
# East         5443
# South        4842
# Southwest    2320
# SouthWest     519
# Unknown       200
# OOJ            16
# FK ERROR       12
# Name: Precinct, dtype: int64

# %%
#impute

# %%
# a lot of missing values again, what do these mean? domain knowledge
df['Sector'].value_counts(dropna=False)
# Out:
# -         9625
# E         2337
# M         2270
# N         2191
# K         1762
# B         1658
# L         1639
# D         1512
# R         1455
# F         1378
# S         1348
# U         1302
# O         1161
# J         1119
# G         1087
# C         1037
# Q          967
# W          941
# K          878
# E          566
# M          495
# D          476
# N          356
# Q          331
# O          320
# F          310
# R          290
# S          267
# G          228
# B          225
# J          218
# U          212
# W          210
# C          188
# L          173
# 99          53
# Name: Sector, dtype: int64

# %%
#impute

# %%
#see sector
df['Beat'].value_counts(dropna=False)
# Out:
# -         9593
# N3        1175
# E2        1092
# M2         852
# M3         792
#           ...
# N1          42
# C2          39
# OOJ         16
# 99          14
# S            2
# Name: Beat, Length: 107, dtype: int64

# %%
#impute

# %% [markdown]
# # EDA

# %% [markdown]
# ## Slow plots first

# %% [markdown]
# ## Pairplot of variables

# %% [markdown]
# ## Correlation matrix heatmap of variables

# %% [markdown]
# ## Stop resolutions

# %%
sns.countplot(y=df['Stop_Resolution'])

# %%
sns.countplot(df['Arrested'])

# %% [markdown]
# ## Stops with weapon vs. none present

# %%
sns.countplot(df['Weapon_Present'])

# %% [markdown]
# ## Stops with weapon present and arrest or not

# %%
sns.barplot(x=df['Weapon_Present'], y=df['Arrested'])

# %% [markdown]
# ## Amount of stops per officer histogram

# %%
df['Officer_ID'].value_counts(dropna=False).hist()

# %%
sns.distplot(df['Officer_ID'].value_counts(dropna=False))

# %% [markdown]
# ## Amount of stops by subject

# %% [markdown]
# ## Distribution and nature of stops by officer YOB

# %%
# sns.scatterplot(x=df['Officer_YOB'], y=)

# %% [markdown]
# ## Officer gender distribution

# %%
sns.countplot(df["Officer_Gender"])

# %% [markdown]
# ## Arrests by female officers

# %%
# sns.scatterplot

# %% [markdown]
# ## Officer Race distribution

# %%
sns.countplot(y=df["Officer_Race"])

# %%
sns.countplot(df['White_Officer'])

# %% [markdown]
# ## Arrests by non-white officers

# %% [markdown]
# ## Suspect? Subject? perceived race

# %%
sns.countplot(y=df['Subject_Perceived_Race'])

# %%
sns.countplot(df['White_Subject'])

# %%
sns.countplot(df['Black_Subject'])

# %% [markdown]
# ## Suspect perceived gender

# %%
sns.countplot(y=df['Subject_Perceived_Gender'])

# %% [markdown]
# ## Stops of female suspects

# %% [markdown]
# ## Suspect age groups

# %% [markdown]
# ## Repeat subjects

# %%
sns.countplot(df['Repeat_Subject'])

# %% [markdown]
# ## Initial and final call types - too small y labels

# %%
sns.countplot(y=df['Initial_Call_Type'])

# %%
sns.countplot(y=df['Final_Call_Type'])

# %% [markdown]
# ## Examination of officer squads

# %% [markdown]
# ## Arrest flags

# %%
sns.countplot(df['Arrest_Flag'])

# %% [markdown]
# ## Nature of arrests

# %% [markdown]
# ## Frisk flags

# %%
sns.countplot(df['Frisk_Flag'])

# %% [markdown]
# ## Nature of frisks

# %%
df_frisks = df[df['Frisk_Flag'] == "Y"] 

df_frisks.head(10)
# Out:
#    Subject_Age_Group  Subject_ID     GO_/_SC_Num  Terry_Stop_ID  \
# 19                 -          -1  20150000004711          81255
# 43                 -          -1  20150000003632          64148
# 54                 -          -1  20150000003007          54535
# 59                 -          -1  20150000003628          64252
# 60                 -          -1  20150000003630          64264
# 65                 -          -1  20150000006280         110365
# 67                 -          -1  20150000006360         112736
# 72                 -          -1  20150000160111          43646
# 80                 -          -1  20150000006048         105028
# 85                 -          -1  20150000120532          35462
#
#    Stop_Resolution                Weapon_Type Officer_ID  \
# 19   Field Contact  Lethal Cutting Instrument     6902
# 43   Field Contact              Firearm Other     6040
# 54   Field Contact                       None     7428
# ...

# %% [markdown]
# ## Arrests by Frisk vs. No Frisk - make subplots

# %%
sns.countplot(y=df_frisks['Stop_Resolution'])

# %%
sns.countplot(y=df['Stop_Resolution'])

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # EDA Part 2
